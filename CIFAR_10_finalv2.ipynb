# %% [markdown]
# # Question No.1. Vision Dataset
#
# CIFAR-10-It dataset consists of 60000 32x32 colour images in 10 classes. Please find your dataset from the link-https://www.tensorflow.org/datasets/catalog/cifar10

# %% [markdown]
# ## 1. Import Libraries/Dataset(0 mark)

# %%
import os
seed=21
os.environ['PYTHONHASHSEED']=str(seed)

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, datasets
from sklearn.model_selection import train_test_split
from tensorflow.keras import utils
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sn
import pandas as pd
import itertools
import copy
import time

# %%
def reset_random_seeds(seed_val):
    os.environ['PYTHONHASHSEED']=str(seed_val)
    tf.random.set_seed(seed_val)
    np.random.seed(seed_val)

# %%
reset_random_seeds(seed)

# %%
(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)
num_classes = 10
print(num_classes)
# Out:
# 10

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=4)

# %% [markdown]
# ## 2. Data Visualization and augmentation(1 mark)

# %% [markdown]
# ### a. Plot at least two samples from each class of the dataset (use matplotlib/seaborn/any other library).

# %%
def display_image(sample_image):
    class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer','dog', 'frog', 'horse', 'ship', 'truck']

    plt.figure(figsize=(5,20))
    # fig, ax = plt.subplots(nrows=10, ncols=2)
    j=1
    for key, value in sample_image.items():
        for i in range(len(value)):
            plt.subplot(10, len(value), j)
            plt.xticks([])
            plt.yticks([])
            plt.grid(False)
            plt.imshow(value[i]/255, cmap=plt.cm.binary)
            plt.xlabel(class_names[key])
            j+=1
    plt.show()

# %%
sample_image = {}

for image, label in zip(X_train, y_train):
    if label[0] in sample_image.keys() and len(sample_image[label[0]])<2:
        sample_image[label[0]].append(image)
    elif label[0] not in sample_image.keys():
        sample_image[label[0]] = [image]

# %%
display_image(sample_image)

# %% [markdown]
# ### b. Apply horizontal flip and width shift augmentation (horizontal_flip, width_shift_range) to the dataset separately. Print the augmented image and the original image for each class and each augmentation.

# %%
width_shift_range_gen = ImageDataGenerator(
    width_shift_range=0.2
)

# %%
horizontal_flip_gen = ImageDataGenerator(
    horizontal_flip=True
)

# %%
width_shift_range_gen.fit(X_train)
horizontal_flip_gen.fit(X_train)

# %%
def get_aug_img(image, gen):
    return next(gen.flow(np.array([image])))[0]

# %%
print("##############################################")
print("      wide_shift_tange augmentation           ")
print("##############################################")

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer','dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(5,20))
# fig, ax = plt.subplots(nrows=10, ncols=2)
j=1
for key, value in sample_image.items():
    value[1] = get_aug_img(value[0], width_shift_range_gen)
    for i in range(len(value)):
        plt.subplot(10, len(value), j)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(value[i]/255, cmap=plt.cm.binary)
        if j%2==1:
            plt.xlabel(class_names[key])
        else:
            plt.xlabel(class_names[key]+'_augmented')
        j+=1
plt.show()
# Out:
# ##############################################
#       wide_shift_tange augmentation
# ##############################################

# %%
print("##############################################")
print("      Horizontal Flip augmentation           ")
print("##############################################")

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer','dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(5,20))
# fig, ax = plt.subplots(nrows=10, ncols=2)
j=1
for key, value in sample_image.items():
    value[1] = get_aug_img(value[0], horizontal_flip_gen)
    for i in range(len(value)):
        plt.subplot(10, len(value), j)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(value[i]/255, cmap=plt.cm.binary)
        if j%2==1:
            plt.xlabel(class_names[key])
        else:
            plt.xlabel(class_names[key]+'_augmented')
        j+=1
plt.show()
# Out:
# ##############################################
#       Horizontal Flip augmentation
# ##############################################

# %%
generator = ImageDataGenerator(
    width_shift_range=0.1,
    horizontal_flip=True,
    samplewise_std_normalization=True 
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:356: UserWarning: This ImageDataGenerator specifies `samplewise_std_normalization`, which overrides setting of `samplewise_center`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
generator.fit(X_train)

# %% [markdown]
# ### c. Bring the train and test data in the required format.

# %%
y_train = utils.to_categorical(y_train, num_classes)
y_valid = utils.to_categorical(y_valid, num_classes)
y_test = utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ### d. Print the shapes of train and test data.

# %%
print("X_train shape: ", X_train.shape)
print("y_train shape: ", y_train.shape)
# Out:
# X_train shape:  (40000, 32, 32, 3)
# y_train shape:  (40000, 10)

# %%
print("X_test shape: ", X_test.shape)
print("y_test shape: ", y_train.shape)
# Out:
# X_test shape:  (10000, 32, 32, 3)
# y_test shape:  (40000, 10)

# %% [markdown]
# ## 3. Model Building(0.2*5 = 1 mark)

# %% [markdown]
# <ol>
# <li>Sequential Model layers-Use AT LEAST 3 hidden layers with appropriate input for each. Choose the best number for hidden units and give reasons.<ul><li>The total number of hidden units chosen was experimenting multiple times. We initially started using 512 unit hidden layer, and started adding new hidden layers by halving the number of neurons in each layer. We constructed the deepnet by adding new hidden layer until we reached overfitting point. Then forward we tried to prevent overfitting by varying regularization parameters and reducing the number of layers when ever necessary</li></ul></li>
# <li>Add L2 regularization to all the layers.</li>
# <li>Add one layer of dropout at the appropriate position and give reasons.<ul><li>The speciality of deep learning is that it minimizes the necessity for handcrafter features. This is achieved by using deep neural networks where each layer tries to learn different feature. The last layer in general tries to act as a classifier. This is the same moto behind the subject behind Respresentational learning. The penultimate leayer in general spits out the learbt feature vector which is used by the last layer to classify. In order to make sure the classifier or last layer generalizes well, we added the dropout layer after the penultimate layer. This will ensure that the features recieved by classifier will be introduced with additional noise thus helping in generalization of the last layer. In general, it is always goog to have dropout after every layer that uses non-linear activation function to prebent overfitting, but since the ask is for using only 1, we have placed it at the current position.</li></ul></li>
# <li>Choose the appropriate activation function for all the layers.</li>
# <li>Print the model summary.</li>
# </ol>

# %%
nodes_per_layer = [512,256,128,64,32,16]
layers = []
batch_size = 64
dropout_rate = 0.3
num_classes = 10

# %%
layers.append(tf.keras.layers.Flatten(input_shape=(32,32,3)))
for nodes in nodes_per_layer:
    layers.append(tf.keras.layers.Dense(nodes, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(l=0.0001))) # Using l2 regularization kernel_regularizer=tf.keras.regularizers.l2(l=0.0001)
layers.append(tf.keras.layers.Dropout(dropout_rate))
layers.append(tf.keras.layers.Dense(10, activation=tf.keras.activations.linear, kernel_regularizer=tf.keras.regularizers.l2(l=0.001)))
layers.append(tf.keras.layers.Softmax())
model = tf.keras.Sequential(layers)

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_7 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_49 (Dense)             (None, 512)               1573376
# _________________________________________________________________
# dense_50 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_51 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_52 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_53 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_54 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_55 (Dense)             (None, 10)                170
# _________________________________________________________________
# softmax_4 (Softmax)          (None, 10)                0
# =================================================================
# Total params: 1,748,634
# Trainable params: 1,748,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 4. Model Compilation(0.25 mark)
# <ol>
# <li>Compile the model with the appropriate loss function.</li>
# <li>Use an appropriate optimizer. Give reasons for the choice of learning rate and its value.<ul><li>We intially choose 0.001(least possible) and use learning rate decay to reduce it for every 10000 steps taken. This helps us converge to optimum better.</li></ul></li>
# <li>Use accuracy as a metric.</li>
# </ol>

# %%
initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=10000,
    decay_rate=0.96,
    staircase=True)
model.compile(optimizer=tf.keras.optimizers.Adam(lr_schedule, amsgrad=False), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 5. Model Training(0.5 + 0.25 = 0.75 mark)

# %% [markdown]
# ### 1. Train the model for an appropriate number of epochs. Print the train and validation accuracy and loss for each epoch. Use the appropriate batch size.

# %%
start_time = time.time()
train_gen = generator.flow(X_train, y_train, batch_size=batch_size, shuffle=False)
valid_gen = generator.flow(X_valid, y_valid, batch_size=batch_size, shuffle=False)
overfitting_hist = model.fit(train_gen,epochs=100,validation_data=valid_gen, callbacks=[callback])
end_time = time.time()
# Out:
# Epoch 1/100
# 625/625 [==============================] - 24s 37ms/step - loss: 2.2875 - accuracy: 0.2022 - val_loss: 1.9737 - val_accuracy: 0.3465
# Epoch 2/100
# 625/625 [==============================] - 23s 36ms/step - loss: 2.0178 - accuracy: 0.3159 - val_loss: 1.8259 - val_accuracy: 0.3892
# Epoch 3/100
# 625/625 [==============================] - 22s 36ms/step - loss: 1.8896 - accuracy: 0.3620 - val_loss: 1.7841 - val_accuracy: 0.4148
# Epoch 4/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.8320 - accuracy: 0.3968 - val_loss: 1.7392 - val_accuracy: 0.4325
# Epoch 5/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.7829 - accuracy: 0.4180 - val_loss: 1.6883 - val_accuracy: 0.4555
# Epoch 6/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.7698 - accuracy: 0.4250 - val_loss: 1.6937 - val_accuracy: 0.4576
# Epoch 7/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.7408 - accuracy: 0.4403 - val_loss: 1.6733 - val_accuracy: 0.4659
# Epoch 8/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.7235 - accuracy: 0.4465 - val_loss: 1.6619 - val_accuracy: 0.4622
# Epoch 9/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.6919 - accuracy: 0.4579 - val_loss: 1.6274 - val_accuracy: 0.4756
# Epoch 10/100
# 625/625 [==============================] - 22s 36ms/step - loss: 1.6836 - accuracy: 0.4613 - val_loss: 1.6433 - val_accuracy: 0.4740
# Epoch 11/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.6691 - accuracy: 0.4688 - val_loss: 1.6280 - val_accuracy: 0.4802
# Epoch 12/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.6520 - accuracy: 0.4766 - val_loss: 1.6032 - val_accuracy: 0.4891
# Epoch 13/100
# 625/625 [==============================] - 22s 36ms/step - loss: 1.6444 - accuracy: 0.4820 - val_loss: 1.5884 - val_accuracy: 0.4941
# Epoch 14/100
# 625/625 [==============================] - 22s 36ms/step - loss: 1.6317 - accuracy: 0.4864 - val_loss: 1.5968 - val_accuracy: 0.4926
# Epoch 15/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.6301 - accuracy: 0.4863 - val_loss: 1.5987 - val_accuracy: 0.4933
# Epoch 16/100
# 625/625 [==============================] - 22s 36ms/step - loss: 1.6196 - accuracy: 0.4917 - val_loss: 1.5803 - val_accuracy: 0.5019
# Epoch 17/100
# 625/625 [==============================] - 22s 36ms/step - loss: 1.6028 - accuracy: 0.4975 - val_loss: 1.5562 - val_accuracy: 0.5089
# Epoch 18/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.5903 - accuracy: 0.5061 - val_loss: 1.5845 - val_accuracy: 0.5012
# Epoch 19/100
# 625/625 [==============================] - 22s 36ms/step - loss: 1.5890 - accuracy: 0.5005 - val_loss: 1.5588 - val_accuracy: 0.5079
# Epoch 20/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.5729 - accuracy: 0.5112 - val_loss: 1.5749 - val_accuracy: 0.4995
# Epoch 21/100
# 625/625 [==============================] - 22s 36ms/step - loss: 1.5724 - accuracy: 0.5115 - val_loss: 1.5614 - val_accuracy: 0.5123
# Epoch 22/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.5677 - accuracy: 0.5146 - val_loss: 1.5720 - val_accuracy: 0.5056
# Epoch 23/100
# 625/625 [==============================] - 22s 36ms/step - loss: 1.5671 - accuracy: 0.5142 - val_loss: 1.5653 - val_accuracy: 0.5158
# Epoch 24/100
# 625/625 [==============================] - 22s 36ms/step - loss: 1.5427 - accuracy: 0.5235 - val_loss: 1.5578 - val_accuracy: 0.5111
# Epoch 25/100
# 625/625 [==============================] - 22s 36ms/step - loss: 1.5532 - accuracy: 0.5188 - val_loss: 1.5623 - val_accuracy: 0.5102
# Epoch 26/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.5408 - accuracy: 0.5236 - val_loss: 1.5740 - val_accuracy: 0.5147
# Epoch 27/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.5350 - accuracy: 0.5275 - val_loss: 1.5600 - val_accuracy: 0.5125

# %% [markdown]
# ### 2. Plot the loss and accuracy history graphs for both train and validation set. Print the total time taken for training

# %%
plt.figure()
plt.plot(overfitting_hist.history['accuracy'])
plt.plot(overfitting_hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')

plt.figure()
plt.plot(overfitting_hist.history['loss'])
plt.plot(overfitting_hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
# darker color graph is train metric and lighter color graph is validation metric
# Out:
# Text(0, 0.5, 'loss')

# %%
print("The total time taken for training: {}s".format(round(end_time - start_time, 2)))
# Out:
# The total time taken for training: 610.44s

# %% [markdown]
# ## 6. Model Evaluation(0.5 + 0.5 = 1 mark)

# %% [markdown]
# ### a. Print the final train and validation loss and accuracy. Print confusion matrix and classification report for the validation dataset. Analyse and report the best and worst performing class.
# The model currently has an training accuracy of

# %%
train_predicted = model.predict(train_gen)
valid_predicted = model.predict(valid_gen)

# %%
train_predicted_cls = np.argmax(train_predicted,axis=1)
valid_predicted_cls = np.argmax(valid_predicted, axis=1)

# %%
train_actual_cls = np.argmax(y_train, axis=1)
valid_actual_cls = np.argmax(y_valid, axis=1)

# %%
print("Train Accuracy: {}%".format(round(accuracy_score(train_actual_cls, train_predicted_cls)*100.0, 2)))
print("Validation Accuracy: {}%".format(round(accuracy_score(valid_actual_cls, valid_predicted_cls)*100.0,2)))
# Out:
# Train Accuracy: 56.38%
# Validation Accuracy: 51.76%

# %%
cfm = confusion_matrix(valid_actual_cls, valid_predicted_cls, normalize='true')

# %%
df_cm = pd.DataFrame(cfm, index = class_names, columns=class_names)

# %%
plt.figure(figsize=(30,30))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, cmap=plt.get_cmap('Blues')) # font size

plt.show()

# %% [markdown]
# ### Analysis of the heatmap
# The best classified class is the truck class, where amongst the truck data in validation dataset, ~67% of them were classified correctly. The worst performing class is the cat class with ~28% of cat images in validation dataset being classified correctly, ~31% of cat images are being misclassifed as dogs!

# %% [markdown]
# ### b. Print the two most incorrectly classified images for each class in the test dataset.

# %%
test_gen = generator.flow(X_test, y_test, batch_size=batch_size, shuffle=False)
test_predicted = model.predict(test_gen)
test_actual_cls = np.argmax(y_test, axis=1)

# %%
def find_2_smallest_index(arr):
    first = 999
    second = 999
    first_index=0
    sexond_index=0
    for i in range(len(arr)):
        if arr[i] < first:
            second = copy.deepcopy(first)
            second_index = copy.deepcopy(first_index)
            first = copy.deepcopy(arr[i])
            first_index = copy.deepcopy(i)
        elif (arr[i] < second):
            second = copy.deepcopy(arr[i])
            second_index = copy.deepcopy(i)
    return first_index, second_index

# %%
worst_2 = {}
for i in range(10):
    first_index, second_index = find_2_smallest_index(test_predicted[:,i])
    worst_2[i] = [X_test[first_index],X_test[second_index]]

# %%
print("#########################################################")
print("  Printing top 2 worst classified images of each class   ")
print("#########################################################")

display_image(worst_2)
# Out:
# #########################################################
#   Printing top 2 worst classified images of each class
# #########################################################

# %% [markdown]
# # Hyperparameter Tuning
# Build two more additional models by changing the following hyperparameters ONE at a time. Write the code for Model Building, Model Compilation, Model Training and Model Evaluation as given in the instructions above for each additional model. <strong>(1 + 1 = 2 marks)</strong>

# %% [markdown]
# ## 1. Batch Size: Change the value of batch size in model training
#
# We will change the batch_size parameter and run the same again. For the change we will double the batch_size and analyze what's happening

# %% [markdown]
# ### 1. Model Building(0.2*5 = 1 mark)

# %% [markdown]
# <ol>
# <li>Sequential Model layers-Use AT LEAST 3 hidden layers with appropriate input for each. Choose the best number for hidden units and give reasons.<ul><li>The total number of hidden units chosen was experimenting multiple times. We initially started using 512 unit hidden layer, and started adding new hidden layers by halving the number of neurons in each layer. We constructed the deepnet by adding new hidden layer until we reached overfitting point. Then forward we tried to prevent overfitting by varying regularization parameters and reducing the number of layers when ever necessary</li></ul></li>
# <li>Add L2 regularization to all the layers.</li>
# <li>Add one layer of dropout at the appropriate position and give reasons.<ul><li>The speciality of deep learning is that it minimizes the necessity for handcrafter features. This is achieved by using deep neural networks where each layer tries to learn different feature. The last layer in general tries to act as a classifier. This is the same moto behind the subject behind Respresentational learning. The penultimate leayer in general spits out the learbt feature vector which is used by the last layer to classify. In order to make sure the classifier or last layer generalizes well, we added the dropout layer after the penultimate layer. This will ensure that the features recieved by classifier will be introduced with additional noise thus helping in generalization of the last layer. In general, it is always goog to have dropout after every layer that uses non-linear activation function to prebent overfitting, but since the ask is for using only 1, we have placed it at the current position.</li></ul></li>
# <li>Choose the appropriate activation function for all the layers.</li>
# <li>Print the model summary.</li>
# </ol>

# %%
epochs = 30
nodes_per_layer = [512,256,128,64,32,16]
layers = []
batch_size = 128 # value changed 
dropout_rate = 0.3
num_classes = 10

# %%
layers.append(tf.keras.layers.Flatten(input_shape=(32,32,3)))
for nodes in nodes_per_layer:
    layers.append(tf.keras.layers.Dense(nodes, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(l=0.0001))) # Using l2 regularization kernel_regularizer=tf.keras.regularizers.l2(l=0.0001)
layers.append(tf.keras.layers.Dropout(dropout_rate))
layers.append(tf.keras.layers.Dense(10, activation=tf.keras.activations.softmax, kernel_regularizer=tf.keras.regularizers.l2(l=0.001)))
model = tf.keras.Sequential(layers)

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_5 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_35 (Dense)             (None, 512)               1573376
# _________________________________________________________________
# dense_36 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_39 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_40 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_41 (Dense)             (None, 10)                170
# =================================================================
# Total params: 1,748,634
# Trainable params: 1,748,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 2. Model Compilation(0.25 mark)
# <ol>
# <li>Compile the model with the appropriate loss function.</li>
# <li>Use an appropriate optimizer. Give reasons for the choice of learning rate and its value.<ul><li>We intially choose 0.001(least possible) and use learning rate decay to reduce it for every 10000 steps taken. This helps us converge to optimum better.</li></ul></li>
# <li>Use accuracy as a metric.</li>
# </ol>

# %%
initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=10000,
    decay_rate=0.96,
    staircase=True)
model.compile(optimizer=tf.keras.optimizers.Adam(lr_schedule), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### 3. Model Training(0.5 + 0.25 = 0.75 mark)

# %% [markdown]
# #### 1. Train the model for an appropriate number of epochs. Print the train and validation accuracy and loss for each epoch. Use the appropriate batch size.

# %%
start_time = time.time()
train_gen = generator.flow(X_train, y_train, batch_size=batch_size, shuffle=False)
valid_gen = generator.flow(X_valid, y_valid, batch_size=batch_size, shuffle=False)
overfitting_hist = model.fit(train_gen,epochs=100,validation_data=valid_gen, shuffle=False, callbacks=[callback])
end_time = time.time()
# Out:
# Epoch 1/100
# 313/313 [==============================] - 22s 69ms/step - loss: 2.2574 - accuracy: 0.2232 - val_loss: 1.9089 - val_accuracy: 0.3884
# Epoch 2/100
# 313/313 [==============================] - 21s 69ms/step - loss: 1.9824 - accuracy: 0.3465 - val_loss: 1.7775 - val_accuracy: 0.4383
# Epoch 3/100
# 313/313 [==============================] - 22s 69ms/step - loss: 1.8718 - accuracy: 0.3784 - val_loss: 1.7401 - val_accuracy: 0.4354
# Epoch 4/100
# 313/313 [==============================] - 21s 68ms/step - loss: 1.8188 - accuracy: 0.3984 - val_loss: 1.6968 - val_accuracy: 0.4549
# Epoch 5/100
# 313/313 [==============================] - 21s 68ms/step - loss: 1.7590 - accuracy: 0.4240 - val_loss: 1.6685 - val_accuracy: 0.4651
# Epoch 6/100
# 313/313 [==============================] - 22s 69ms/step - loss: 1.7315 - accuracy: 0.4365 - val_loss: 1.6463 - val_accuracy: 0.4735
# Epoch 7/100
# 313/313 [==============================] - 21s 69ms/step - loss: 1.7095 - accuracy: 0.4441 - val_loss: 1.6246 - val_accuracy: 0.4858
# Epoch 8/100
# 313/313 [==============================] - 21s 68ms/step - loss: 1.6880 - accuracy: 0.4574 - val_loss: 1.6344 - val_accuracy: 0.4828
# Epoch 9/100
# 313/313 [==============================] - 22s 69ms/step - loss: 1.6692 - accuracy: 0.4701 - val_loss: 1.6125 - val_accuracy: 0.4911
# Epoch 10/100
# 313/313 [==============================] - 22s 69ms/step - loss: 1.6486 - accuracy: 0.4783 - val_loss: 1.6122 - val_accuracy: 0.4919
# Epoch 11/100
# 313/313 [==============================] - 22s 69ms/step - loss: 1.6322 - accuracy: 0.4859 - val_loss: 1.5943 - val_accuracy: 0.5016
# Epoch 12/100
# 313/313 [==============================] - 22s 69ms/step - loss: 1.6205 - accuracy: 0.4877 - val_loss: 1.6083 - val_accuracy: 0.4924
# Epoch 13/100
# 313/313 [==============================] - 22s 69ms/step - loss: 1.6107 - accuracy: 0.4922 - val_loss: 1.6268 - val_accuracy: 0.4951
# Epoch 14/100
# 313/313 [==============================] - 22s 70ms/step - loss: 1.5963 - accuracy: 0.5013 - val_loss: 1.5867 - val_accuracy: 0.5025
# Epoch 15/100
# 313/313 [==============================] - 22s 70ms/step - loss: 1.5946 - accuracy: 0.4989 - val_loss: 1.5894 - val_accuracy: 0.5047
# Epoch 16/100
# 313/313 [==============================] - 22s 69ms/step - loss: 1.5820 - accuracy: 0.5097 - val_loss: 1.5989 - val_accuracy: 0.4997
# Epoch 17/100
# 313/313 [==============================] - 22s 69ms/step - loss: 1.5747 - accuracy: 0.5114 - val_loss: 1.5953 - val_accuracy: 0.5075
# Epoch 18/100
# 313/313 [==============================] - 22s 70ms/step - loss: 1.5618 - accuracy: 0.5178 - val_loss: 1.5836 - val_accuracy: 0.5107
# Epoch 19/100
# 313/313 [==============================] - 22s 69ms/step - loss: 1.5565 - accuracy: 0.5182 - val_loss: 1.5990 - val_accuracy: 0.5069
# Epoch 20/100
# 313/313 [==============================] - 22s 70ms/step - loss: 1.5483 - accuracy: 0.5260 - val_loss: 1.5739 - val_accuracy: 0.5152
# Epoch 21/100
# 313/313 [==============================] - 22s 70ms/step - loss: 1.5401 - accuracy: 0.5299 - val_loss: 1.5649 - val_accuracy: 0.5232
# Epoch 22/100
# 313/313 [==============================] - 22s 70ms/step - loss: 1.5218 - accuracy: 0.5356 - val_loss: 1.5691 - val_accuracy: 0.5190
# Epoch 23/100
# 313/313 [==============================] - 22s 69ms/step - loss: 1.5223 - accuracy: 0.5380 - val_loss: 1.5650 - val_accuracy: 0.5208
# Epoch 24/100
# 313/313 [==============================] - 22s 69ms/step - loss: 1.5165 - accuracy: 0.5355 - val_loss: 1.5764 - val_accuracy: 0.5204
# Epoch 25/100
# 313/313 [==============================] - 22s 70ms/step - loss: 1.5030 - accuracy: 0.5433 - val_loss: 1.6056 - val_accuracy: 0.5105

# %% [markdown]
# #### 2. Plot the loss and accuracy history graphs for both train and validation set. Print the total time taken for training

# %%
plt.figure()
plt.plot(overfitting_hist.history['accuracy'])
plt.plot(overfitting_hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')

plt.figure()
plt.plot(overfitting_hist.history['loss'])
plt.plot(overfitting_hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
# darker color graph is train metric and lighter color graph is validation metric
# Out:
# Text(0, 0.5, 'loss')

# %%
print("The total time taken for training: {}s".format(round(end_time - start_time, 2)))
# Out:
# The total time taken for training: 541.91s

# %% [markdown]
# ### 4. Model Evaluation(0.5 + 0.5 = 1 mark)

# %% [markdown]
# #### a. Print the final train and validation loss and accuracy. Print confusion matrix and classification report for the validation dataset. Analyse and report the best and worst performing class.

# %%
train_predicted = model.predict(train_gen)
valid_predicted = model.predict(valid_gen)

# %%
train_predicted_cls = np.argmax(train_predicted,axis=1)
valid_predicted_cls = np.argmax(valid_predicted, axis=1)

# %%
train_actual_cls = np.argmax(y_train, axis=1)
valid_actual_cls = np.argmax(y_valid, axis=1)

# %%
print("Train Accuracy: {}%".format(round(accuracy_score(train_actual_cls, train_predicted_cls)*100.0, 2)))
print("Validation Accuracy: {}%".format(round(accuracy_score(valid_actual_cls, valid_predicted_cls)*100.0,2)))
# Out:
# Train Accuracy: 57.09%
# Validation Accuracy: 51.37%

# %%
cfm = confusion_matrix(valid_actual_cls, valid_predicted_cls, normalize='true')

# %%
df_cm = pd.DataFrame(cfm, index = class_names, columns=class_names)

# %%
plt.figure(figsize=(30,30))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, cmap=plt.get_cmap('Blues')) # font size

plt.show()

# %% [markdown]
# ### Analysis of Heatmap
# For the validation dataset, amongst the classes, model has learnt to classify automobile better than other classes as it could identify ~73% of automobile data in validation set, the next best are ship and horse. The worst classified class is dog, amongst the dog images present in validation set, it has properly classified only ~28% of them. It has mostly classified dogs as cats which is totally wrong!

# %% [markdown]
# #### b. Print the two most incorrectly classified images for each class in the test dataset.

# %%
test_gen = generator.flow(X_test, y_test, batch_size=batch_size, shuffle=False)
test_predicted = model.predict(test_gen)
test_actual_cls = np.argmax(y_test, axis=1)

# %%
def find_2_smallest_index(arr):
    first = 999
    second = 999
    first_index=0
    sexond_index=0
    for i in range(len(arr)):
        if arr[i] < first:
            second = copy.deepcopy(first)
            second_index = copy.deepcopy(first_index)
            first = copy.deepcopy(arr[i])
            first_index = copy.deepcopy(i)
        elif (arr[i] < second):
            second = copy.deepcopy(arr[i])
            second_index = copy.deepcopy(i)
    return first_index, second_index

# %%
worst_2 = {}
for i in range(10):
    first_index, second_index = find_2_smallest_index(test_predicted[:,i])
    worst_2[i] = [X_test[first_index],X_test[second_index]]

# %%
print("#########################################################")
print("  Printing top 2 worst classified images of each class   ")
print("#########################################################")

display_image(worst_2)
# Out:
# #########################################################
#   Printing top 2 worst classified images of each class
# #########################################################

# %% [markdown]
# # Analysis on how much the performance was affected by changing batch_size
# We can see that as we doubled the batch size, the model is converging faster. The time taken to reach the previous levels was more quicker. But since we kept everything else same, we need to change the learning rate appropriatly as well as the the parameters for learning rate decay to converge better and faster!

# %% [markdown]
# ## 2. Dropout: Change the position and value of dropout layer

# %% [markdown]
# We will change the position of the droput layer to just after the flatten layer to introduce noice in data and analyze model behavior and also reduce the dropout rate value as we want lesser noise in the data

# %% [markdown]
# ### 1. Model Building(0.2*5 = 1 mark)

# %% [markdown]
# <ol>
# <li>Sequential Model layers-Use AT LEAST 3 hidden layers with appropriate input for each. Choose the best number for hidden units and give reasons.</li>
# <li>Add L2 regularization to all the layers.</li>
# <li>Add one layer of dropout at the appropriate position and give reasons.</li>
# <li>Choose the appropriate activation function for all the layers.</li>
# <li>Print the model summary.</li>
# </ol>

# %%
epochs = 30
nodes_per_layer = [512,256,128,64,32,16]
layers = []
batch_size = 64
dropout_rate = 0.2 # new change
num_classes = 10

# %%
layers.append(tf.keras.layers.Flatten(input_shape=(32,32,3)))
layers.append(tf.keras.layers.Dropout(dropout_rate)) # new change
for nodes in nodes_per_layer:
    layers.append(tf.keras.layers.Dense(nodes, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(l=0.0001))) # Using l2 regularization kernel_regularizer=tf.keras.regularizers.l2(l=0.0001)
layers.append(tf.keras.layers.Dense(10, activation=tf.keras.activations.linear, kernel_regularizer=tf.keras.regularizers.l2(l=0.001)))
layers.append(tf.keras.layers.Softmax())
model = tf.keras.Sequential(layers)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_6 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 3072)              0
# _________________________________________________________________
# dense_42 (Dense)             (None, 512)               1573376
# _________________________________________________________________
# dense_43 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_44 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_45 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_46 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_47 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_48 (Dense)             (None, 10)                170
# _________________________________________________________________
# softmax_3 (Softmax)          (None, 10)                0
# =================================================================
# Total params: 1,748,634
# Trainable params: 1,748,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 2. Model Compilation(0.25 mark)
# <ol>
# <li>Compile the model with the appropriate loss function.</li>
# <li>Use an appropriate optimizer. Give reasons for the choice of learning rate and its value.</li>
# <li>Use accuracy as a metric.</li>
# </ol>

# %%
initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=10000,
    decay_rate=0.96,
    staircase=True)
model.compile(optimizer=tf.keras.optimizers.Adam(lr_schedule), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### 3. Model Training(0.5 + 0.25 = 0.75 mark)

# %% [markdown]
# #### 1. Train the model for an appropriate number of epochs. Print the train and validation accuracy and loss for each epoch. Use the appropriate batch size.

# %%
start_time = time.time()
train_gen = generator.flow(X_train, y_train, batch_size=batch_size, shuffle=False)
valid_gen = generator.flow(X_valid, y_valid, batch_size=batch_size, shuffle=False)
overfitting_hist = model.fit(train_gen,epochs=100,validation_data=valid_gen, shuffle=False, callbacks=[callback])
end_time = time.time()
# Out:
# Epoch 1/100
# 625/625 [==============================] - 24s 37ms/step - loss: 2.1147 - accuracy: 0.2847 - val_loss: 1.8257 - val_accuracy: 0.4169
# Epoch 2/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.8033 - accuracy: 0.4161 - val_loss: 1.7386 - val_accuracy: 0.4465
# Epoch 3/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.7263 - accuracy: 0.4446 - val_loss: 1.7146 - val_accuracy: 0.4556
# Epoch 4/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.6721 - accuracy: 0.4646 - val_loss: 1.6779 - val_accuracy: 0.4690
# Epoch 5/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.6424 - accuracy: 0.4795 - val_loss: 1.6479 - val_accuracy: 0.4820
# Epoch 6/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.6156 - accuracy: 0.4914 - val_loss: 1.6412 - val_accuracy: 0.4923
# Epoch 7/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.5953 - accuracy: 0.5009 - val_loss: 1.6350 - val_accuracy: 0.4919
# Epoch 8/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.5826 - accuracy: 0.5047 - val_loss: 1.6338 - val_accuracy: 0.5003
# Epoch 9/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.5651 - accuracy: 0.5158 - val_loss: 1.6192 - val_accuracy: 0.4968
# Epoch 10/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.5516 - accuracy: 0.5229 - val_loss: 1.6179 - val_accuracy: 0.5033
# Epoch 11/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.5403 - accuracy: 0.5264 - val_loss: 1.5936 - val_accuracy: 0.5146
# Epoch 12/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.5226 - accuracy: 0.5357 - val_loss: 1.5953 - val_accuracy: 0.5117
# Epoch 13/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.5071 - accuracy: 0.5387 - val_loss: 1.6120 - val_accuracy: 0.5110
# Epoch 14/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.5025 - accuracy: 0.5450 - val_loss: 1.5917 - val_accuracy: 0.5194
# Epoch 15/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.4924 - accuracy: 0.5497 - val_loss: 1.5969 - val_accuracy: 0.5191
# Epoch 16/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.4847 - accuracy: 0.5511 - val_loss: 1.5883 - val_accuracy: 0.5279
# Epoch 17/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.4727 - accuracy: 0.5527 - val_loss: 1.6145 - val_accuracy: 0.5161
# Epoch 18/100
# 625/625 [==============================] - 23s 37ms/step - loss: 1.4534 - accuracy: 0.5620 - val_loss: 1.5945 - val_accuracy: 0.5229
# Epoch 19/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.4547 - accuracy: 0.5661 - val_loss: 1.6000 - val_accuracy: 0.5202
# Epoch 20/100
# 625/625 [==============================] - 23s 36ms/step - loss: 1.4376 - accuracy: 0.5702 - val_loss: 1.6196 - val_accuracy: 0.5185

# %% [markdown]
# #### 2. Plot the loss and accuracy history graphs for both train and validation set. Print the total time taken for training

# %%
plt.figure()
plt.plot(overfitting_hist.history['accuracy'])
plt.plot(overfitting_hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')

plt.figure()
plt.plot(overfitting_hist.history['loss'])
plt.plot(overfitting_hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
# darker color graph is train metric and lighter color graph is validation metric
# Out:
# Text(0, 0.5, 'loss')

# %%
print("The total time taken for training: {}s".format(round(end_time - start_time, 2)))
# Out:
# The total time taken for training: 460.09s

# %% [markdown]
# ### 4. Model Evaluation(0.5 + 0.5 = 1 mark)

# %% [markdown]
# #### a. Print the final train and validation loss and accuracy. Print confusion matrix and classification report for the validation dataset. Analyse and report the best and worst performing class.

# %%
train_predicted = model.predict(train_gen)
valid_predicted = model.predict(valid_gen)

# %%
train_predicted_cls = np.argmax(train_predicted,axis=1)
valid_predicted_cls = np.argmax(valid_predicted, axis=1)

# %%
train_actual_cls = np.argmax(y_train, axis=1)
valid_actual_cls = np.argmax(y_valid, axis=1)

# %%
print("Train Accuracy: {}%".format(round(accuracy_score(train_actual_cls, train_predicted_cls)*100.0, 2)))
print("Validation Accuracy: {}%".format(round(accuracy_score(valid_actual_cls, valid_predicted_cls)*100.0,2)))
# Out:
# Train Accuracy: 57.87%
# Validation Accuracy: 52.26%

# %%
cfm = confusion_matrix(valid_actual_cls, valid_predicted_cls, normalize='true')

# %%
df_cm = pd.DataFrame(cfm, index = class_names, columns=class_names)

# %%
plt.figure(figsize=(30,30))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, cmap=plt.get_cmap('Blues')) # font size

plt.show()

# %% [markdown]
# ### Analysis of Heatmap
# For the validation dataset, amongst the classes, model has learnt to classify automobile better than other classes as it could identify ~71% of automobile data in validation set, the next best are Horse and truck. The worst classified class is dog, amongst the dog images present in validation set, it has properly classified only ~25% of them. It has mostly classified dogs as cats which is totally wrong!

# %% [markdown]
# #### b. Print the two most incorrectly classified images for each class in the test dataset.

# %%
test_gen = generator.flow(X_test, y_test, batch_size=batch_size, shuffle=False)
test_predicted = model.predict(test_gen)
test_actual_cls = np.argmax(y_test, axis=1)

# %%
def find_2_smallest_index(arr):
    first = 999
    second = 999
    first_index=0
    sexond_index=0
    for i in range(len(arr)):
        if arr[i] < first:
            second = copy.deepcopy(first)
            second_index = copy.deepcopy(first_index)
            first = copy.deepcopy(arr[i])
            first_index = copy.deepcopy(i)
        elif (arr[i] < second):
            second = copy.deepcopy(arr[i])
            second_index = copy.deepcopy(i)
    return first_index, second_index

# %%
worst_2 = {}
for i in range(10):
    first_index, second_index = find_2_smallest_index(test_predicted[:,i])
    worst_2[i] = [X_test[first_index],X_test[second_index]]

# %%
print("#########################################################")
print("  Printing top 2 worst classified images of each class   ")
print("#########################################################")

display_image(worst_2)
# Out:
# #########################################################
#   Printing top 2 worst classified images of each class
# #########################################################

# %% [markdown]
# # Analysis of moving the dropout layer
# By introducing the noise in data, we would ideally like to see if data is being modeled better, this has reduced the overiting but by a small value. It can be better to have more than one dropout layers. In general, it is better to have dropout layers after having layer with non-linear activation functions!

# %% [markdown]
# # References
#
#
# 1. Sashank J. Reddi, Satyen Kale, & Sanjiv Kumar. (2019). On the Convergence of Adam and Beyond.
# 2. Srivastava, Nitish, Geoffrey, Hinton, Alex, Krizhevsky, Ilya, Sutskever, and Ruslan, Salakhutdinov. "Dropout: A Simple Way to Prevent Neural Networks from Overfitting".J. Mach. Learn. Res. 15, no.1 (2014): 1929–1958.
# 3. "Is Dropout Applied before or after the Non-linear Activation Function?" Dr. Sebastian Raschka. May 19, 2021. Accessed May 23, 2021. https://sebastianraschka.com/faq/docs/dropout-activation.html.
# 4. Franck DernoncourtFranck Dernoncourt "Where Should I Place Dropout Layers in a Neural Network?" Cross Validated. June 01, 1965. Accessed May 23, 2021. https://stats.stackexchange.com/questions/240305/where-should-i-place-dropout-layers-in-a-neural-network.
# 5. Galeone, Paolo. "Analysis of Dropout." P. Galeone's Blog. Accessed May 23, 2021. https://pgaleone.eu/deep-learning/regularization/2017/01/10/anaysis-of-dropout/.
# 6. Shen, Kevin. "Effect of Batch Size on Training Dynamics." Medium. June 19, 2018. Accessed May 23, 2021. https://medium.com/mini-distill/effect-of-batch-size-on-training-dynamics-21c14f7a716e.
# 7. Samuel L. Smith, , Pieter-Jan Kindermans, Chris Ying, and Quoc V. Le. "Don't Decay the Learning Rate, Increase the Batch Size." (2018).
